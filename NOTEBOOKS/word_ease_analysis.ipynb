# %% [markdown]
# # Word ease analysis
# Several popular readability measures use as a feature the number of "difficult words," which in some cases are defined as any word not on a list of "easy" words. This seems likely to become less useful over time as diction changes. The purpose of this notebook is to investigate how much these word lists have been affected by the change in English word use, using Google n-gram data.

# %% [markdown]
# ## The easy word lists
# 1. Dale and Chall made the first "easy" word list, which was generated by selecting words that 80% of surveyed 4th graders said they were familiar with. The original list was made in 1948. The one we are going to use was updated in 1995.
# 2. The Spache formula was proposed by George Spache in 1953. It was intended to help classify reading material grade level for the first few grades in particular, and therefore it uses a subset containing 769 of the **original** Dale-Chall easy words. This list does not appear to have been updated since then.

# %%
# %pylab inline
import pandas as pd
from tqdm.notebook import tqdm
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# The years we are concerned with are the year that each word list was constructed and the last year of the ngrams data, 2008.

# %%
years = [1953, 1995, 2008]

# %% [markdown]
# ## Get the n-gram "A" data
# Let's restrict ourselves to just the words on the list that begin with the letter "A." We'll also only consider words longer than 1 character, since it is probable that kids will continue to remember the one-character words like "a" and "I."

# %%
# !wget http://storage.googleapis.com/books/ngrams/books/googlebooks-eng-all-1gram-20120701-a.gz
# Out:
# --2021-09-27 21:15:22--  http://storage.googleapis.com/books/ngrams/books/googlebooks-eng-all-1gram-20120701-a.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.122.128, 142.250.65.80, 172.253.115.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.122.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 343487895 (328M) [binary/octet-stream]
# Saving to: ‘googlebooks-eng-all-1gram-20120701-a.gz’
#
# googlebooks-eng-all 100%[===================>] 327.58M  19.6MB/s    in 16s
#
# 2021-09-27 21:15:39 (20.1 MB/s) - ‘googlebooks-eng-all-1gram-20120701-a.gz’ saved [343487895/343487895]

# %%
! gunzip googlebooks-eng-all-1gram-20120701-a.gz
# Out:
# gzip: googlebooks-eng-all-1gram-20120701-a: No space left on device

# %%
! head ../Data/ngrams/googlebooks-eng-all-1gram-20120701-a
# Out:
# A'Aang_NOUN	1879	45	5
# A'Aang_NOUN	1882	5	4
# A'Aang_NOUN	1885	1	1
# A'Aang_NOUN	1891	1	1
# A'Aang_NOUN	1899	20	4
# A'Aang_NOUN	1927	3	1
# A'Aang_NOUN	1959	5	2
# A'Aang_NOUN	1962	2	2
# A'Aang_NOUN	1963	1	1
# A'Aang_NOUN	1966	45	13

# %%
! mv googlebooks-eng-all-1gram-20120701-a* ../Data/ngrams/

# %%
df_a = pd.read_csv("../Data/ngrams/googlebooks-eng-all-1gram-20120701-a", delimiter="\t", names=["word", "year", "counts", "num_books"])#, dtype={"word":str, "year": int, "counts": int, "num_books":int})

# %%
df_a.head()
# Out:
#           word  year  counts  num_books
# 0  A'Aang_NOUN  1879      45          5
# 1  A'Aang_NOUN  1882       5          4
# 2  A'Aang_NOUN  1885       1          1
# 3  A'Aang_NOUN  1891       1          1
# 4  A'Aang_NOUN  1899      20          4

# %%
df_a.shape
# Out:
# (86618505, 4)

# %%
df_a[df_a["year"]==2008].shape
# Out:
# (1212585, 4)

# %%
df_a = df_a[(df_a["year"]==1953)|(df_a["year"]==1995)|(df_a["year"]==2008)]

# %%
df_a.shape
# Out:
# (2687817, 4)

# %%
sums = df_a.groupby(["year"]).sum()

# %%
sums
# Out:
#           counts  num_books
# year
# 1953   299648748   17700512
# 1995  1542556650   92813649
# 2008  3679259804  226938787

# %%
sums.loc[1953]["counts"]
# Out:
# 299648748

# %% [markdown]
# ## Get the "A" words that are easy
# This requires that we interact with the Spache and Dale-Chall lists.

# %%
# !wget https://raw.githubusercontent.com/cdimascio/py-readability-metrics/3ffb97f6057ae2451599d083a69ece78a61a6fa4/readability/data/spache_easy.txt
# Out:
# --2021-09-27 21:16:25--  https://raw.githubusercontent.com/cdimascio/py-readability-metrics/3ffb97f6057ae2451599d083a69ece78a61a6fa4/readability/data/spache_easy.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5978 (5.8K) [text/plain]
# Saving to: ‘spache_easy.txt’
#
# spache_easy.txt     100%[===================>]   5.84K  --.-KB/s    in 0s
#
# 2021-09-27 21:16:25 (83.4 MB/s) - ‘spache_easy.txt’ saved [5978/5978]

# %%
# !wget https://raw.githubusercontent.com/cdimascio/py-readability-metrics/3ffb97f6057ae2451599d083a69ece78a61a6fa4/readability/data/dale_chall_easy.txt
# Out:
# --2021-09-27 21:16:25--  https://raw.githubusercontent.com/cdimascio/py-readability-metrics/3ffb97f6057ae2451599d083a69ece78a61a6fa4/readability/data/dale_chall_easy.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18727 (18K) [text/plain]
# Saving to: ‘dale_chall_easy.txt’
#
# dale_chall_easy.txt 100%[===================>]  18.29K  --.-KB/s    in 0s
#
# 2021-09-27 21:16:26 (111 MB/s) - ‘dale_chall_easy.txt’ saved [18727/18727]

# %%
! mv *easy.txt ../Data

# %%
with open("../Data/dale_chall_easy.txt", "r") as file_obj:
    dale_chall_words = file_obj.readlines()

# %%
dale_chall_words = [word.strip().lower() for word in dale_chall_words]

# %%
with open("../Data/spache_easy.txt", "r") as file_obj:
    spache_words = file_obj.readlines()

# %%
spache_words = [word.strip().lower().replace("\\", "'") for word in spache_words]

# %%
spache_a_words = [word for word in spache_words if (word[0]=='a' and len(word)>=2)]
dale_chall_a_words = [word for word in dale_chall_words if (word[0]=='a' and len(word)>=2)]

# %%
len(spache_words)
# Out:
# 1064

# %%
len(dale_chall_words)
# Out:
# 2950

# %%
len(set(spache_words).intersection(set(dale_chall_words)))
# Out:
# 1006

# %%
for word in spache_words:
    if word not in dale_chall_words:
        print(word)
# Out:
# b
# baby
# c
# comfortable
# contest
# continue
# d
# disappear
# disappoint
# distance
# dragon
# e
# excite
# exclaim
# fierce
# final
# g
# gasp
# grin
# growl
# h
# imagine
# j
# jet
# k
# l
# m
# n
# o
# p
# perfect
# picket
# practice
# pretend
# probably
# problem
# q
# r
# raccoon
# reply
# s
# scold
# signal
# sniff
# special
# strike
# t
# traffic
# trot
# u
# usual
# v
# w
# x
# y
# z
# zoo

# %%
len(dale_chall_a_words)
# Out:
# 125

# %% [markdown]
# ## Compare
# We'll look at how word popularity has changed using the Google N-Grams data to show how common each word of interest was during the years the lists were published and a more recent year.

# %%
def just_word(text):
    return text.split("_")[0].lower()

df_a["just_word"] = df_a["word"].apply(just_word)

# %%
dale_chall_data = np.zeros(shape=(len(dale_chall_a_words), len(years)))
for j in tqdm(range(len(years))):
    for i in tqdm(range(len(dale_chall_a_words))):
        word = dale_chall_a_words[i]
        year = years[j]
        dale_chall_data[i][j] = df_a[(df_a["just_word"]==word) & (df_a["year"]==year)]["counts"].sum()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]

# %%
for i in range(len(years)):
    dale_chall_data[:,i] = dale_chall_data[:,i]/sums.loc[years[i]]["counts"]

# %%
relative_change = array([(dale_chall_data[i][2]-dale_chall_data[i][1])/dale_chall_data[i][1] for i in range(len(dale_chall_a_words))] )
relative_change = array([relative_change]).transpose()
dale_chall_data = np.append(array([array(dale_chall_a_words)]).transpose(), dale_chall_data, axis=1)
dale_chall_data = np.append(dale_chall_data, relative_change, axis=1)

# %%
dale_chall_data = dale_chall_data[dale_chall_data[:,4].argsort()][::-1]

# %%
print(f"{'WORD':<15}{'1995':<25}{'2008':<25}{'RELATIVE CHANGE':<25}")
for i in range(len(dale_chall_a_words)):
    print(f"{dale_chall_data[i][0]:<15}{dale_chall_data[i][2]:<25}{dale_chall_data[i][3]:<25}{dale_chall_data[i][4]:<25}")
# Out:
# WORD           1995                     2008                     RELATIVE CHANGE
# afterwards     0.0001442883799437771    0.0004942192443227638    2.425218610918908
# afar           1.745673327459319e-05    4.3087199177304955e-05   1.4682280756397166
# aren't         1.555858580623279e-07    3.677370101804314e-07    1.3635632104372588
# anyhow         2.6807443344139096e-05   6.29156439967456e-05     1.346946823278499
# airship        4.130804531554806e-06    9.08198979688035e-06     1.1986007150674722
# ah             0.00019594482964369574   0.0004228837002237421    1.1581773859137283
# awfully        1.8672896065113718e-05   4.023417966816675e-05    1.1546834260667067
# awhile         2.9913326035708315e-05   6.346765720271489e-05    1.1217184985364683
# awful          9.843204137754033e-05    0.00019544909528220966   0.9856247269378092
# axe            3.435789538102215e-05    6.654680915270316e-05    0.9368709408627166
# armful         2.303967248139639e-06    4.29597278855277e-06     0.8645980284752728
# afterward      8.514954701987769e-05    0.00015575660065564645   0.8292123224012683
# aunt           0.00019884131970128942   0.00034879271058945854   0.754125908606091
# admire         5.3536445484838435e-05   9.288553084195301e-05    0.7349962254826625
# ashes          5.589681260652567e-05    9.679147952879927e-05    0.7316099973381909
# awaken         2.654943012951907e-05    4.529470841358394e-05    0.7060520015916604
# asleep         0.00013573893704325218   0.00022887918898374158   0.6861719560306485
# awake          9.291522616041363e-05    0.0001546615434390781    0.6645446589352585
# airy           1.99305484177842e-05     3.312486926514418e-05    0.6620149416253179
# apiece         1.0797010275116963e-05   1.775710427651007e-05    0.6446315993079584
# aloud          8.853678080477628e-05    0.00014329132164758648   0.6184383523447055
# am             0.002280948968713726     0.0036679350518624043    0.6080741402692705
# alarm          0.0001146538119037638    0.00018043303146960914   0.5737203017816626
# afraid         0.0003657441041144259    0.0005502970999217864    0.504595955836985
# arose          0.00014825387450114068   0.00021999370610360953   0.4838985277374109
# alike          0.0001606093364545153    0.00023492660101368586   0.4627206998032601
# away           0.002592547897673645     0.0037903153739887404    0.46200399128204384
# afternoon      0.00035309886350041016   0.0005111740133043347    0.4476795768665535
# apron          2.874513555142367e-05    4.072993155772263e-05    0.4169330141045513
# ape            2.149029664485904e-05    3.043900294245163e-05    0.4164068298114126
# again          0.003275343566798665     0.004601867468449097     0.4050029789537415
# arm            0.0005670034873597673    0.0007927132508634338    0.39807473593271253
# angel          0.0001737103139777719    0.00024071254740889726   0.3857124651775081
# arrived        0.0005463176992559722    0.0007547153905742504    0.3814587951334804
# anybody        0.00015297590529333234   0.00020977290028850596   0.3712806594363014
# anything       0.001401381271799645     0.0019111602264007992    0.36376892203397243
# ant            4.3142661891866336e-05   5.846746668069761e-05    0.3552123146050116
# adventure      0.00012097319083872867   0.00016362856445893974   0.352601872567581
# alone          0.001195132120431363     0.0016116287829289699    0.3484942420820213
# aching         2.7154270152736368e-05   3.621733911128827e-05    0.3337622004780196
# ago            0.0007549738935033602    0.000967620714397368     0.28166115772195416
# alive          0.0003300650254886911    0.0004188108701442493    0.26887382122405096
# ate            0.00014086808416404026   0.00017865658719870057   0.26825453940763305
# all            0.020256397066519403     0.025604244608544095     0.2640078353748225
# army           0.0009924795954819553    0.0012458620059982042    0.2553023877465255
# angry          0.00028583974533447445   0.00035755072217781336   0.2508782561341375
# always         0.003004071195699685     0.003713137622178094     0.23603516038282799
# aside          0.0003564822076388572    0.00044057611757606664   0.23589931877442472
# attend         0.0002492459515182149    0.0003076732985176276    0.23441643342055585
# answer         0.0011863194781209494    0.0014508793301838817    0.22300894231457563
# ask            0.0011847726953820464    0.001423673042687909     0.20164234729331432
# attack         0.0006202475610863303    0.0007412395822211418    0.1950705310681118
# alley          5.2642475075388644e-05   6.260933238516146e-05    0.18933109234509599
# aboard         8.340115093990227e-05    9.834967337903164e-05    0.1792364046618622
# almost         0.002148925940580529     0.0025327420449811756    0.17860834436060607
# any            0.009220802360807948     0.010843458773046188     0.17597778899753572
# aim            0.00033706379600386153   0.0003901420602153269    0.15747245726401687
# acre           8.583931099062067e-05    9.906122954507183e-05    0.15403104244273194
# anywhere       0.00021730936105328775   0.0002498793368710964    0.14987838379324103
# autumn         0.00015755401916681634   0.00018116252602638986   0.14984388836553325
# across         0.0016067643285580468    0.001843257437984393     0.14718593462837293
# apartment      0.00022601114843983202   0.00025898279837810554   0.14588505994451478
# acorn          9.674847273842423e-06    1.1041351294582294e-05   0.1412429552696346
# ache           3.3245456495876504e-05   3.783043530893857e-05    0.13791294499537848
# at             0.035241934226532295     0.03989014470803052      0.13189430669780788
# arrive         0.00020716581138203254   0.00023011095848125653   0.11075740222845484
# against        0.004043282948473886     0.004469211981747837     0.1053423761586401
# after          0.008463559506874512     0.00930598485129429      0.09953558473069395
# already        0.0020559659834859224    0.0022450219446367753    0.09195480988956133
# as             0.06229639994096813      0.06648457027526616      0.06722973299045737
# account        0.0016243636822025306    0.0017334367073144042    0.06714815549432733
# and            0.2490775648336805       0.2644520147618257       0.06172555098814862
# air            0.001955491877721314     0.002067647952376021     0.05735440578019661
# another        0.004925769825049861     0.005207595282934252     0.057214500046505634
# acts           0.0006611290418410241    0.0006987658216484024    0.05692803889324292
# attention      0.0014314255492658891    0.0015038155212591232    0.05057194349392432
# able           0.0020823598277573793    0.0021796096028015095    0.04670171492352714
# accident       0.0002775398880812578    0.0002873561684474076    0.03536889934637354
# alligator      1.3045225924117601e-05   1.346874171433206e-05    0.03246519398575359
# ahead          0.0004393524218381218    0.000452612505969149     0.03018097425194765
# along          0.002189968193388554     0.0022347622723084006    0.020454214383148865
# anger          0.00037271759192766113   0.000380316986171711     0.020389148268388616
# around         0.0032185339838248406    0.003275610759234115     0.01773378056472945
# anyway         0.00028146972754614877   0.000285687082727143     0.01498333486077216
# about          0.013440499575817848     0.01364102691129229      0.014919634076342756
# animal         0.0007065335331444716    0.0007090393554605311    0.0035466431506898143
# airplane       7.294837437574821e-05    4.208808517181844e-05    -0.4230428637788715
# automobile     0.00013971674881437904   8.600615799296787e-05    -0.384424854408604
# auto           0.0001373466575765629    9.377538374020189e-05    -0.3172357784685989
# airfield       1.4680173982589229e-05   1.0275164574923289e-05   -0.30006520446489987
# avenue         0.00026838171551106407   0.0001919358886350609    -0.2848399218643928
# american       0.0044063730171595315    0.0031664915283595996    -0.2813836876659147
# ax             4.038555083212017e-05    3.0289788146746486e-05   -0.24998452360699608
# arrow          0.00018135411752949235   0.00014270424704153348   -0.2131182407902788
# airport        0.00016408084591253098   0.00013218473984122052   -0.194392623306646
# also           0.013507223219322285     0.01101272868959922      -0.18467855970238606
# april          0.0009506535789139414    0.0007871219088283769    -0.17202025397347007
# america        0.0016903690376622472    0.001403896238690297     -0.1694735247683768
# age            0.002417449628187075     0.002064470411070759     -0.14601305979683504
# arithmetic     8.301024147152067e-05    7.136979011770815e-05    -0.14022909881314047
# august         0.0008331979250162385    0.0007183007291648166    -0.13789904223439178
# address        0.0009957909811610485    0.0008597212940932073    -0.13664482772196831
# accept         0.0006863644197443251    0.0005968651622841473    -0.130396120319752
# amount         0.001547159386334369     0.0013525959744918302    -0.12575524768880547
# appear         0.001184975605271936     0.0010646369673980218    -0.10155368375393531
# arise          0.00031894906420454637   0.0002877635873522565    -0.0977757277014308
# are            0.04318477639054617      0.03926349284792176      -0.09080245101101984
# add            0.0009542826190532452    0.0008691587901793086    -0.08920190641048135
# arrange        0.00013263435090050016   0.0001223882041465099    -0.07725107925982704
# anyone         0.0007478882542174383    0.0006913276407484705    -0.07562709154745403
# agree          0.0004887710282795773    0.00045642686014569903   -0.06617447897377701
# an             0.03194079971066217      0.02995570709091464      -0.062149120802535325
# aid            0.0006631834234418554    0.0006228668596625149    -0.06079247815046636
# artist         0.0003666542813840905    0.00034458371181661734   -0.06019449570903287
# apple          0.00018604308632684576   0.00017521758025870575   -0.05818816641818903
# art            0.0018782733198161635    0.0017694496574887702    -0.057938139875215
# act            0.0026233396355329966    0.0024801542935563785    -0.054581320709366124
# aged           0.0002379517147717071    0.00022500041967680518   -0.05442824863576839
# absent         0.00022375839486997123   0.00021248757675390296   -0.050370481619775094
# ash            0.00010099142874266562   9.679963334277222e-05    -0.04150644715181161
# allow          0.0009986965470603624    0.0009574050726644473    -0.04134536613494406
# apart          0.0005315078703916644    0.0005194411652915174    -0.02270277783705283
# above          0.002620715420727012     0.002562578752864825     -0.022183510427110465
# among          0.0033876772045940743    0.003372737904104801     -0.0044098949182685135
# author         0.001018389178770193     0.0010178261931730658    -0.0005528196968934502

# %%
spache_data = np.zeros(shape=(len(spache_a_words), len(years)))
for j in tqdm(range(len(years))):
    for i in tqdm(range(len(spache_a_words))):
        word = spache_a_words[i]
        year = years[j]
        spache_data[i][j] = df_a[(df_a["just_word"]==word) & (df_a["year"]==year)]["counts"].sum()
        
for i in range(len(years)):
    spache_data[:,i] = spache_data[:,i]/sums.loc[years[i]]["counts"]     
    
relative_change = array([(spache_data[i][2]-spache_data[i][1])/spache_data[0][1] for i in range(len(spache_a_words))] )
relative_change = array([relative_change]).transpose()
spache_data = np.append(array([array(spache_a_words)]).transpose(), spache_data, axis=1)
spache_data = np.append(spache_data, relative_change, axis=1)    

spache_data = spache_data[spache_data[:,4].argsort()][::-1]

print(f"{'WORD':<15}{'1953':<25}{'2008':<25}{'RELATIVE CHANGE':<25}")
for i in range(len(spache_a_words)):
    print(f"{spache_data[i][0]:<15}{spache_data[i][1]:<25}{spache_data[i][3]:<25}{spache_data[i][4]:<25}")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/47 [00:00<?, ?it/s]
#   0%|          | 0/47 [00:00<?, ?it/s]
#   0%|          | 0/47 [00:00<?, ?it/s]
# WORD           1953                     2008                     RELATIVE CHANGE
# and            0.2513751000221099       0.2644520147618257       7.3831860004247805
# all            0.02464184832836345      0.025604244608544095     2.5681668800651596
# at             0.0403861557265709       0.03989014470803052      2.232184092076039
# as             0.06584835121687209      0.06648457027526616      2.011261588161028
# any            0.012590291216568007     0.010843458773046188     0.7792392028546662
# am             0.002472778561384144     0.0036679350518624043    0.6660645603418158
# again          0.0038527309314838184    0.004601867468449097     0.6370291454762873
# away           0.002600881883210805     0.0037903153739887404    0.5751971683035418
# after          0.0092745723736513       0.00930598485129429      0.4045532060263752
# always         0.0035258715647962595    0.003713137622178094     0.34051099960089315
# against        0.004954314042386721     0.004469211981747837     0.2045415146779222
# alone          0.0014199758979136466    0.0016116287829289699    0.200011860076151
# almost         0.0029261760840061978    0.0025327420449811756    0.18431785865462144
# another        0.005220252079945283     0.005207595282934252     0.1353394615703408
# answer         0.0011934807082858228    0.0014508793301838817    0.1270480963647157
# ask            0.0008238979860513216    0.001423673042687909     0.1147257760745169
# across         0.001259431259162144     0.001843257437984393     0.11356976170686124
# arm            0.0004932475139191972    0.0007927132508634338    0.10839133587529257
# ago            0.0008557519486115123    0.000967620714397368     0.10211819209123917
# about          0.011328390399281761     0.01364102691129229      0.09629811947073647
# already        0.0024582148429333666    0.0022450219446367753    0.09078928561278427
# afraid         0.00037816276809539683   0.0005502970999217864    0.08862685178003886
# afternoon      0.00043672133080295734   0.0005111740133043347    0.07591154405536403
# aunt           0.00016975876034696464   0.00034879271058945854   0.07201031679988801
# air            0.0027272164674620966    0.002067647952376021     0.05386008371833345
# able           0.002079738374211395     0.0021796096028015095    0.04670171492352714
# asleep         0.00012929137951879578   0.00022887918898374158   0.04472822165456286
# attention      0.0014120966726014822    0.0015038155212591232    0.03476343090578889
# angry          0.0001902894651840828    0.00035755072217781336   0.03443736086695874
# alarm          0.00011684347167704502   0.00018043303146960914   0.03158878628420671
# awake          8.896750004108143e-05    0.0001546615434390781    0.029652088200896033
# around         0.0018145512158121882    0.003275610759234115     0.027409660255856776
# along          0.002281564680523878     0.0022347622723084006    0.021511209697167553
# ate            0.0001347544425581915    0.00017865658719870057   0.01814696121724412
# animal         0.0008356917947142566    0.0007090393554605311    0.0012033570195974191
# are            0.04325473437319351      0.03926349284792176      -1.8830960386166715
# also           0.010696977782800548     0.01101272868959922      -1.1979171401945163
# an             0.03072800758039543      0.02995570709091464      -0.9532899133409599
# act            0.0034690717279419435    0.0024801542935563785    -0.06876109501729256
# appear         0.0013899607549836984    0.0010646369673980218    -0.05778955023518405
# add            0.0006895840592666184    0.0008691587901793086    -0.04087853969292697
# above          0.0034341541784115846    0.002562578752864825     -0.027918646473697004
# anyone         0.0006147597853470758    0.0006913276407484705    -0.027161786697489917
# arrow          0.00010129526721733542   0.00014270424704153348   -0.018560610886151834
# airplane       9.633946476559282e-05    4.208808517181844e-05    -0.014819863883546535
# among          0.003690120540733913     0.003372737904104801     -0.007174216621995891
# apple          0.00011293890004839933   0.00017521758025870575   -0.005198672162149161

# %%
counter = 0
for i in range(len(dale_chall_a_words)):
    if float(dale_chall_data[i][4]) < 0:
        counter += 1
print(f"Out of the simple word list, {counter} out of {len(dale_chall_a_words)} words have become less popular ({counter/len(dale_chall_a_words)*100}%).")
# Out:
# Out of the simple word list, 39 out of 125 words have become less popular (31.2%).

# %%
counter = 0
for i in range(len(spache_a_words)):
    if float(spache_data[i][4]) < 0:
        counter += 1
print(f"Out of the simple word list, {counter} out of {len(spache_data)} words have become less popular ({counter/len(spache_data)*100}%).")
# Out:
# Out of the simple word list, 12 out of 47 words have become less popular (25.53191489361702%).

# %% [markdown]
# ## Conclusion

# %% [markdown]
# While the Google N-Grams data is not necessarily a good way of predicting the words that a 4th grader might know, it does give insight into relative word popularity over time, and it is obvious from this data that the majority of words considered as "easy" in standard lists have become less popular over time, and in some cases this is an extreme change, e.g. "Airfield." The task of keeping such a list up-to-date is daunting.
